# %% [markdown]
# Name: `Christian Jay Baguio` </br>
# Course: `Exploratory Data Analysis`

# %% [markdown]
# # About the data

# %% [markdown]
# ### Food consumption
# Description:	The relative consumption of certain food items in European and Scandinavian countries. The numbers represent the percentage of the population consuming that food type.
#
# Data source:	Uncertain.
#
# Data shape:	16 rows and 20 columns
#
# Usage restrictions:	Unknown
#
# Contact person:	Kevin Dunn
#
# Contact details:	kgdunn@gmail.com
#
# Added here on:	27 March 2011 20:05
#
# Last updated:	11 November 2018 16:33

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('food-consumption.csv')
df.head()
# Out:
#    Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0  Germany           90              49   88       19.0      57.0
# 1    Italy           82              10   60        2.0      55.0
# 2   France           88              42   63        4.0      76.0
# 3  Holland           96              62   98       32.0      62.0
# 4  Belgium           94              38   48       11.0      74.0
#
#    Powder soup  Tin soup  Potatoes  Frozen fish  ...  Apples  Oranges  \
# 0           51        19        21           27  ...      81       75
# 1           41         3         2            4  ...      67       71
# 2           53        11        23           11  ...      87       84
# 3           67        43         7           14  ...      83       89
# 4           37        23         9           13  ...      76       76
#
#    Tinned fruit  Jam  Garlic  Butter  Margarine  Olive oil  Yoghurt  \
# 0            44   71      22      91         85         74     30.0
# ...

# %% [markdown]
# Check for nan values.

# %%
df.isna().sum()
# Out:
# Country           0
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         1
# Biscuits          1
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           1
# Crisp bread       0
# dtype: int64

# %%
df.describe()
# Out:
#        Real coffee  Instant coffee        Tea  Sweetener   Biscuits  \
# count    16.000000       16.000000  16.000000  16.000000  16.000000
# mean     78.562500       39.250000  78.500000  18.000000  60.666667
# std      23.145824       23.147354  18.540047  10.532489  19.168261
# min      27.000000       10.000000  40.000000   2.000000  22.000000
# 25%      71.500000       17.000000  62.500000  11.000000  56.500000
# 50%      89.000000       39.000000  84.500000  18.500000  62.000000
# 75%      96.000000       54.250000  92.250000  25.750000  74.500000
# max      98.000000       86.000000  99.000000  35.000000  91.000000
#
#        Powder soup   Tin soup   Potatoes  Frozen fish  Frozen veggies  \
# count    16.000000  16.000000  16.000000    16.000000        16.00000
# mean     49.000000  18.312500  12.750000    21.875000        15.87500
# std      15.427249  20.178268   9.574271    13.980343        12.78997
# min      27.000000   1.000000   2.000000     4.000000         2.00000
# ...

# %%
#check mean for each attributes
mean = df.mean()
mean
# Out:
# C:\Users\ATARA\AppData\Local\Temp\ipykernel_18376\2523297653.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean = df.mean()
# Real coffee       78.562500
# Instant coffee    39.250000
# Tea               78.500000
# Sweetener         18.000000
# Biscuits          60.666667
# Powder soup       49.000000
# Tin soup          18.312500
# Potatoes          12.750000
# Frozen fish       21.875000
# Frozen veggies    15.875000
# Apples            66.812500
# Oranges           70.500000
# Tinned fruit      41.937500
# Jam               55.187500
# Garlic            42.312500
# Butter            75.812500
# Margarine         69.125000
# Olive oil         54.187500
# Yoghurt           20.533333
# Crisp bread       27.750000
# dtype: float64

# %%
#Fill each attributes with nan values with their mean values
df = df.fillna(df.mean())
df
# Out:
# C:\Users\ATARA\AppData\Local\Temp\ipykernel_18376\983163164.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = df.fillna(df.mean())
#         Country  Real coffee  Instant coffee  Tea  Sweetener   Biscuits  \
# 0       Germany           90              49   88       19.0  57.000000
# 1         Italy           82              10   60        2.0  55.000000
# 2        France           88              42   63        4.0  76.000000
# 3       Holland           96              62   98       32.0  62.000000
# 4       Belgium           94              38   48       11.0  74.000000
# 5    Luxembourg           97              61   86       28.0  79.000000
# 6       England           27              86   99       22.0  91.000000
# ...

# %% [markdown]
# Check again for nan values.

# %%
df.isna().sum()
# Out:
# Country           0
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         0
# Biscuits          0
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           0
# Crisp bread       0
# dtype: int64
