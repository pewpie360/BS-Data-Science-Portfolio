# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Christian Jay Baguio
# ## DS3A

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('ggplot')

# %%
# Create a n sample
n_samples = 100

age = np.random.randint(20, 65, size=n_samples)  # Random ages between 18 and 65
income = np.random.normal(50000, 15000, n_samples)  # Random incomes with a mean of 50,000 and standard deviation of 15,000

# Create a categorical data
gender = np.random.choice(['Male', 'Female'], size=n_samples)
education = np.random.choice(['High School', 'Bachelor', 'Master', 'Ph.D.'], size=n_samples)

df = pd.DataFrame({
    'Age': age,
    'Income': income,
    'Gender': gender,
    'Education': education
})

# %% [markdown]
# # Item Number 3 Problem

# %% [markdown]
# # Bot Plot

# %%
sns.boxplot(x='Education', y='Income', data=df)
plt.xlabel('Education')
plt.ylabel('Income')
plt.title('Box Plot of Income by Education')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The box plot shows the median, quartiles, and potential outliers of income for each level of education. It helps us understand how 'Income' varies among different educational groups.

# %% [markdown]
# # Bar Plot

# %%
mean_income_by_education = df.groupby('Education')['Income'].mean()
mean_income_by_education.plot(kind='bar')
plt.xlabel('Education')
plt.ylabel('Mean Income')
plt.title('Mean Income by Education')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The bar plot makes it easy to compare the mean income levels for each education category.
